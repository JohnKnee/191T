# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

datapath = os.path.join("datasets", "housing", "")
housing_data = pd.read_csv(datapath + "housing.csv")
x = housing_data.housing_median_age
y = housing_data.population
plt.plot(x, y, 'bo')
